# %%
import open3d as o3d 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import struct
import sys
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D 
from matplotlib import cm
from pyntcloud import PyntCloud

sys.path.insert(0,'/home/shrisha/masters/WS-20/AVG/data/pyntcloud')
from pyntcloud import *

# %%
predictions_path = "/home/shrisha/masters/WS-20/AVG/data/voxel_data/preds-adam-sanitycheck-binary"

# %%
for npz in os.listdir(predictions_path):
    path = os.path.join(predictions_path, npz)
    batch = np.load(path)
    gt = batch['gt'][0]
    pred = batch['pred'][0]
    pred[pred > 0.5] = 1
    pred[pred < 0.5] = 0
    
    n_size = pred.flatten().shape[0]
    voxel_colors = np.full((n_size, 3), (0, 0, 1), dtype=np.float)
    
    scaled_shape = np.array([1.46257542, 1.4125462 , 1.])
    voxel_centers = (np.argwhere(pred) * scaled_shape).astype(np.float32)
#     plot.voxelgrid.plot_voxelgrid_with_pythreejs(voxel_centers, voxel_colors, width=800, height=500)

# %%
voxel_centers
# Out:
# array([[ 0.     ,  0.     ,  0.     ],
#        [ 0.     ,  0.     ,  1.     ],
#        [ 0.     ,  0.     ,  2.     ],
#        ...,
#        [92.14225, 88.99041, 13.     ],
#        [92.14225, 88.99041, 14.     ],
#        [92.14225, 88.99041, 15.     ]], dtype=float32)

# %%
pred
# Out:
# array([[[5.73347956e-02, 2.12955847e-02, 1.60298850e-02, ...,
#          7.90671166e-03, 1.07722180e-02, 4.11048234e-02],
#         [1.81403160e-02, 4.74673789e-03, 3.27173038e-03, ...,
#          1.00850209e-03, 1.40956487e-03, 9.70264710e-03],
#         [1.54517824e-02, 4.66955081e-03, 3.25803622e-03, ...,
#          7.43212935e-04, 9.73703340e-04, 6.82468200e-03],
#         ...,
#         [1.27411205e-02, 3.42097203e-03, 2.27555772e-03, ...,
#          1.10476813e-03, 1.30426197e-03, 8.51317868e-03],
#         [1.71439853e-02, 4.59478842e-03, 3.05544981e-03, ...,
#          1.71387277e-03, 2.18738429e-03, 1.30913518e-02],
#         [5.26047908e-02, 2.19789930e-02, 1.61393657e-02, ...,
#          1.15393428e-02, 1.50577910e-02, 6.14156835e-02]],
#
#        [[1.67696550e-02, 4.59468132e-03, 3.23882676e-03, ...,
#          1.04076753e-03, 1.47799018e-03, 9.90201347e-03],
#         [3.23172868e-03, 6.67531742e-04, 4.67095524e-04, ...,
#          6.61555241e-05, 9.15054261e-05, 1.14347902e-03],
#         [3.05020763e-03, 8.92622396e-04, 6.71082467e-04, ...,
#          5.68823598e-05, 6.37411213e-05, 7.28928950e-04],
#         ...,
#         [2.30574701e-03, 5.75206243e-04, 4.21996258e-04, ...,
#          1.23439051e-04, 1.15769879e-04, 1.12218992e-03],
#         [3.23368027e-03, 6.78438053e-04, 4.50349064e-04, ...,
#          1.65019330e-04, 1.81115625e-04, 1.71904906e-03],
#         [1.56661123e-02, 4.71887970e-03, 3.25743272e-03, ...,
#          1.80930737e-03, 2.27077003e-03, 1.46948425e-02]],
#
#        [[1.36487512e-02, 3.70890531e-03, 2.58617033e-03, ...,
#          6.64767460e-04, 8.92045908e-04, 6.34431513e-03],
#         [2.80316407e-03, 6.52098330e-04, 4.89211292e-04, ...,
