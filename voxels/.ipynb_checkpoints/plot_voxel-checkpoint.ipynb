# %%
import open3d as o3d 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import struct
import sys
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D 
from pyntcloud import PyntCloud

# %%
o3d.__version__
# Out:
# '0.11.1'

# %%
sys.path.insert(1, '/home/shrisha/masters/WS-20/AVG/data/utils-avg/pointcloud/')
from downsample_pointcloud import downsample

# %%
def voxelize(pcd, x, y, z):
    # cloud = PyntCloud.from_file(path)
    cloud = PyntCloud.from_instance("open3d", pcd)
    voxelgrid_id = cloud.add_structure("voxelgrid", n_x=x, n_y=y, n_z=z)
    voxelgrid = cloud.structures[voxelgrid_id]

    x_cords = voxelgrid.voxel_x
    y_cords = voxelgrid.voxel_y
    z_cords = voxelgrid.voxel_z
    # import pdb;pdb.set_trace()
    voxel = np.zeros((x, y, z)).astype(np.bool)

    for x, y, z in zip(x_cords, y_cords, z_cords):
        voxel[x][y][z] = True
    return voxel, voxelgrid, cloud

# %%
input_folder = "../../voxel_data/single/"
f = "400_cropped.ply"

# %%
pcd_points = downsample(o3d.io.read_point_cloud(os.path.join(input_folder, f)), 0.4)
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(pcd_points)
cloud = PyntCloud.from_instance("open3d", pcd)
voxelgrid_id = cloud.add_structure("voxelgrid", n_x=64, n_y=64, n_z=16, regular_bounding_box=False)
voxelgrid = cloud.structures[voxelgrid_id]
# voxels, voxelgrid, pcd_new = voxelize(pcd, 64, 64, 16)

# %%
voxelgrid.plot(d=3, mode="density", cmap="cool")
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(34.67023849487305, 93.40960693359375, 80.901…

# %%
pcd_new
# Out:
# PyntCloud
# 61786 points with 0 scalar fields
# 0 faces in mesh
# 0 kdtrees
# 1 voxelgrids
# Centroid: 1013.1672216771543, 3825.984391092516, 116.66462945793445
# Other attributes:

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.voxels(voxels)
plt.show()
